# %% [markdown]
# # ch 16_9 Granger Causality Test
#
# 지금까지 하나의 시계열 변수를 예측하는 모델들에 대해서 알아보았습니다. 그런데 시계열 변수가 2개가 주어졌고, 이들간에 인과 관계가 있는지 여부를 알고 싶다면 어떻게 할 수 있을까요? 이 때 적용할 수 있는 기법이 Granger Causality Test입니다.

# %%
import warnings

warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## 데이터 셋 준비
#
# 사용할 데이터 셋은 미국 휴스턴 가정집의 3년치 전력 소비량과 날씨 데이터 셋을 전처리한 것입니다. 결측치를 제거하고, 전력 소비량과 날씨 데이터를 조인하였습니다. 이 데이터 셋을 먼저 플랏을 그려보고, 시계열 데이터 간의 인과 관계를 검정해보겠습니다.
#
# 데이터 셋 링크: https://www.kaggle.com/datasets/srinuti/residential-power-usage-3years-data-timeseries

# %%
from utils import load_power

train_df, test_df = load_power()

# %%
train_df
# Out:
#                  kWh  Temp_avg  Dew_avg  Hum_avg  Wind_avg  Press_avg  \
# Date
# 2017-01-01  0.508333      67.5     63.8     88.1       2.7       29.7
# 2017-01-02  0.361833      68.8     60.2     76.1       7.9       29.9
# 2017-01-03  0.658833      73.6     54.4     55.5      11.2       29.9
# 2017-01-04  0.474167      70.6     62.7     77.0      12.9       29.8
# 2017-01-05  0.693417      70.7     49.0     50.6       7.1       29.9
# ...              ...       ...      ...      ...       ...        ...
# 2019-06-27  0.968667      79.6     75.8     89.1       4.0       30.0
# 2019-06-28  1.145458      78.5     73.2     85.7       4.3       30.0
# 2019-06-29  1.155583      75.9     73.0     91.7       6.5       29.9
# 2019-06-30  1.285708      77.9     71.8     82.8       3.4       29.9
# 2019-07-01  0.416250      67.7     61.1     80.1       6.3       30.0
#
#             Precipit
# Date
# 2017-01-01      0.30
# 2017-01-02      0.00
# 2017-01-03      0.00
# 2017-01-04      0.00
# 2017-01-05      0.00
# ...              ...
# 2019-06-27      0.02
# 2019-06-28      0.08
# 2019-06-29      0.38
# 2019-06-30      0.80
# 2019-07-01      0.00
#
# [912 rows x 7 columns]

# %%
from utils import plot_multiple_timeseries

plot_multiple_timeseries(train_df, ["kWh", "Temp_avg", "Wind_avg"])

# %%
plot_multiple_timeseries(test_df, ["kWh", "Temp_avg"])

# %% [markdown]
# ## Granger Causality
#
# ### 기본 개념
#
# Granger Causality는 일반적으로 말하는 인과 관계는 아니지만, 유사한 방법으로 인과관계를 추측할 수 있게 해주는 방법 중 하나입니다. x와 y 두 시계열 데이터가 주어졌을 때, y를 예측하는데 x의 과거 데이터가 유용하게 사용된다면 둘 사이에 인과관계가 있다고 보는 방법입니다.
#
# ![1920px-GrangerCausalityIllustration.svg.png](attachment:124ca70f-8957-443d-bcfb-ec63cf26d923.png)

# %% [markdown]
# x와 y 두 시계열 데이터로 auto regressive 모델을 구성하면 아래와 같습니다. y의 현재 값을 예측할 때 x의 과거 값을 피쳐로 사용하고, x의 현재 값을 예측할 때 y의 과거 값을 피쳐로 사용하는 모델입니다.
#
# $$y_{t}=\alpha+\sum_{j=1}^{p}\beta_{j}y_{t-j}+\sum_{j=1}^{r}\gamma_{j}x_{t-j}+\epsilon_{t}$$
#
# $$x_{t}=\alpha^{*}+\sum_{j=1}^{p}\beta_{j}^{*}x_{t-j}+\sum_{j=1}^{r}\gamma_{j}^{*}y_{t-j}+\epsilon_{t}^{*}$$

# %% [markdown]
# 만약 x의 과거 값이 y를 예측하는데 도움이 된다면 어느 j에 대해서 γj는 0이 아닐 것입니다. 마찬가지로 y의 과거 값이 x의 현재 값을 예측하는데 도움이 된다면 어떤 γ*j는 0이 아닐 것입니다. 이를 통계 기법을 활용하여 검정하는 것이 Granger Causality Test입니다.
#
# $$x_{t}\;\text{helps to predict}\;y_{t}\;\text{if}\;\gamma_{j}\neq0\;\text{for some j}$$
#
# $$y_{t}\;\text{helps to predict}\;x_{t}\;\text{if}\;\gamma_{j}^{*}\neq0\;\text{for some j}$$

# %% [markdown]
# ### 가설 설정
#
# 이제 Granger Test의 귀무 가설과 대립가설을 살펴보겠습니다.
#
# - 귀무가설: x는 y를 Granger-cause 하지 않는다.
# - 대립가설: x는 y를 Granger-cause 한다.
#
#
# $$H_{0}:\gamma_{j}^{*}=0\;\text{for all j=1,2,...,r*}$$
#
# $$H_{1}:\gamma_{j}^{*}\neq0\;\text{for some j}$$

# %% [markdown]
# ### 정상성 확보
#
# Granger Causality는 두 시계열 데이터가 stationary 해야한다는 전제 조건이 있습니다. kWh, Temp_avg 두 컬럼에 대해서 정상성 테스트를 진행해보겠습니다.

# %%
from utils import stationary_test

stationary_test(train_df, "kWh")
stationary_test(train_df, "Temp_avg")
stationary_test(train_df, "Temp_avg")
# Out:
# kWh ADF p-value: 0.0 stationary: True
# kWh KPSS p-value: 0.1 stationary: True
# Temp_avg ADF p-value: 0.0036 stationary: True
# Temp_avg KPSS p-value: 0.1 stationary: True

# %% [markdown]
# 두 데이터 모두 정상성이 확보되어 있음을 확인했습니다.

# %% [markdown]
# ### 통계적 가설 검정 진행
#
# statsmodels에 내장된 함수를 사용해 Granger Causality Test를 진행해보겠습니다. 두번째에 위치한 데이터가 첫번째에 위치한 데이터를 유발하는지를 검정합니다. 이 때, 몇번째 지연까지 포함할 지를 결정하는 maxlag라는 파라미터를 설정해주어야 합니다. 이는 여러가지 기준에 의해서 정할 수 있지만, 넉넉하게 12로 설정한 뒤에 테스트를 진행해보겠습니다.

# %%
from statsmodels.tsa.stattools import grangercausalitytests

result = grangercausalitytests(train_df[["kWh", "Temp_avg"]], maxlag=12)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=39.1827 , p=0.0000  , df_denom=908, df_num=1
# ssr based chi2 test:   chi2=39.3122 , p=0.0000  , df=1
# likelihood ratio test: chi2=38.4876 , p=0.0000  , df=1
# parameter F test:         F=39.1827 , p=0.0000  , df_denom=908, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=17.1794 , p=0.0000  , df_denom=905, df_num=2
# ssr based chi2 test:   chi2=34.5486 , p=0.0000  , df=2
# likelihood ratio test: chi2=33.9089 , p=0.0000  , df=2
# parameter F test:         F=17.1794 , p=0.0000  , df_denom=905, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=12.7034 , p=0.0000  , df_denom=902, df_num=3
# ssr based chi2 test:   chi2=38.4061 , p=0.0000  , df=3
# likelihood ratio test: chi2=37.6169 , p=0.0000  , df=3
# parameter F test:         F=12.7034 , p=0.0000  , df_denom=902, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=12.3928 , p=0.0000  , df_denom=899, df_num=4
# ssr based chi2 test:   chi2=50.0676 , p=0.0000  , df=4
# likelihood ratio test: chi2=48.7360 , p=0.0000  , df=4
# parameter F test:         F=12.3928 , p=0.0000  , df_denom=899, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=10.8378 , p=0.0000  , df_denom=896, df_num=5
# ssr based chi2 test:   chi2=54.8543 , p=0.0000  , df=5
# likelihood ratio test: chi2=53.2596 , p=0.0000  , df=5
# parameter F test:         F=10.8378 , p=0.0000  , df_denom=896, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=10.4938 , p=0.0000  , df_denom=893, df_num=6
# ssr based chi2 test:   chi2=63.8794 , p=0.0000  , df=6
# likelihood ratio test: chi2=61.7280 , p=0.0000  , df=6
# parameter F test:         F=10.4938 , p=0.0000  , df_denom=893, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=10.2345 , p=0.0000  , df_denom=890, df_num=7
# ssr based chi2 test:   chi2=72.8488 , p=0.0000  , df=7
# likelihood ratio test: chi2=70.0652 , p=0.0000  , df=7
# parameter F test:         F=10.2345 , p=0.0000  , df_denom=890, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=8.9733  , p=0.0000  , df_denom=887, df_num=8
# ssr based chi2 test:   chi2=73.1623 , p=0.0000  , df=8
# likelihood ratio test: chi2=70.3524 , p=0.0000  , df=8
# parameter F test:         F=8.9733  , p=0.0000  , df_denom=887, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=8.2934  , p=0.0000  , df_denom=884, df_num=9
# ssr based chi2 test:   chi2=76.2453 , p=0.0000  , df=9
# likelihood ratio test: chi2=73.1969 , p=0.0000  , df=9
# parameter F test:         F=8.2934  , p=0.0000  , df_denom=884, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=10.4462 , p=0.0000  , df_denom=881, df_num=10
# ssr based chi2 test:   chi2=106.9517, p=0.0000  , df=10
# likelihood ratio test: chi2=101.0715, p=0.0000  , df=10
# parameter F test:         F=10.4462 , p=0.0000  , df_denom=881, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=10.1383 , p=0.0000  , df_denom=878, df_num=11
# ssr based chi2 test:   chi2=114.4433, p=0.0000  , df=11
# likelihood ratio test: chi2=107.7373, p=0.0000  , df=11
# parameter F test:         F=10.1383 , p=0.0000  , df_denom=878, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=9.7148  , p=0.0000  , df_denom=875, df_num=12
# ssr based chi2 test:   chi2=119.9088, p=0.0000  , df=12
# likelihood ratio test: chi2=112.5664, p=0.0000  , df=12
# parameter F test:         F=9.7148  , p=0.0000  , df_denom=875, df_num=12

# %% [markdown]
# 검정 결과 모든 lag에서 평균 기온의 변화는 전력 소요량의 변화를 유의하게 유발한다고 해석할 수 있습니다. 그렇다면 평균 풍속의 변화는 전력 소요량에 유의미한 변화를 미치는지 검정해보겠습니다.

# %%
result = grangercausalitytests(train_df[["kWh", "Wind_avg"]], maxlag=12)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3235  , p=0.5697  , df_denom=908, df_num=1
# ssr based chi2 test:   chi2=0.3246  , p=0.5689  , df=1
# likelihood ratio test: chi2=0.3245  , p=0.5689  , df=1
# parameter F test:         F=0.3235  , p=0.5697  , df_denom=908, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.6115  , p=0.5428  , df_denom=905, df_num=2
# ssr based chi2 test:   chi2=1.2297  , p=0.5407  , df=2
# likelihood ratio test: chi2=1.2288  , p=0.5410  , df=2
# parameter F test:         F=0.6115  , p=0.5428  , df_denom=905, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8506  , p=0.4664  , df_denom=902, df_num=3
# ssr based chi2 test:   chi2=2.5716  , p=0.4625  , df=3
# likelihood ratio test: chi2=2.5680  , p=0.4631  , df=3
# parameter F test:         F=0.8506  , p=0.4664  , df_denom=902, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6444  , p=0.6309  , df_denom=899, df_num=4
# ssr based chi2 test:   chi2=2.6034  , p=0.6262  , df=4
# likelihood ratio test: chi2=2.5997  , p=0.6269  , df=4
# parameter F test:         F=0.6444  , p=0.6309  , df_denom=899, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5265  , p=0.7563  , df_denom=896, df_num=5
# ssr based chi2 test:   chi2=2.6649  , p=0.7515  , df=5
# likelihood ratio test: chi2=2.6609  , p=0.7521  , df=5
# parameter F test:         F=0.5265  , p=0.7563  , df_denom=896, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5313  , p=0.7847  , df_denom=893, df_num=6
# ssr based chi2 test:   chi2=3.2344  , p=0.7789  , df=6
# likelihood ratio test: chi2=3.2286  , p=0.7797  , df=6
# parameter F test:         F=0.5313  , p=0.7847  , df_denom=893, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.7267  , p=0.6494  , df_denom=890, df_num=7
# ssr based chi2 test:   chi2=5.1727  , p=0.6389  , df=7
# likelihood ratio test: chi2=5.1580  , p=0.6407  , df=7
# parameter F test:         F=0.7267  , p=0.6494  , df_denom=890, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.7257  , p=0.6689  , df_denom=887, df_num=8
# ssr based chi2 test:   chi2=5.9172  , p=0.6565  , df=8
# likelihood ratio test: chi2=5.8979  , p=0.6587  , df=8
# parameter F test:         F=0.7257  , p=0.6689  , df_denom=887, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.5814  , p=0.8131  , df_denom=884, df_num=9
# ssr based chi2 test:   chi2=5.3452  , p=0.8032  , df=9
# likelihood ratio test: chi2=5.3295  , p=0.8047  , df=9
# parameter F test:         F=0.5814  , p=0.8131  , df_denom=884, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.5455  , p=0.8582  , df_denom=881, df_num=10
# ssr based chi2 test:   chi2=5.5852  , p=0.8488  , df=10
# likelihood ratio test: chi2=5.5680  , p=0.8502  , df=10
# parameter F test:         F=0.5455  , p=0.8582  , df_denom=881, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=0.5004  , p=0.9037  , df_denom=878, df_num=11
# ssr based chi2 test:   chi2=5.6483  , p=0.8958  , df=11
# likelihood ratio test: chi2=5.6306  , p=0.8968  , df=11
# parameter F test:         F=0.5004  , p=0.9037  , df_denom=878, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.5445  , p=0.8860  , df_denom=875, df_num=12
# ssr based chi2 test:   chi2=6.7209  , p=0.8755  , df=12
# likelihood ratio test: chi2=6.6959  , p=0.8770  , df=12
# parameter F test:         F=0.5445  , p=0.8860  , df_denom=875, df_num=12

# %% [markdown]
# 평균 풍속의 경우에는 모든 lag에서 전력 소요량의 변화를 유발하지 못한다고 검정되었습니다. 마지막으로 그렇다면 처음에 진행했던 테스트를 뒤집어서 전력 소요량의 변화가 평균 기온의 변화를 유발하는지 검정해보겠습니다.

# %%
result = grangercausalitytests(train_df[["Temp_avg", "kWh"]], maxlag=12)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=25.6097 , p=0.0000  , df_denom=908, df_num=1
# ssr based chi2 test:   chi2=25.6943 , p=0.0000  , df=1
# likelihood ratio test: chi2=25.3386 , p=0.0000  , df=1
# parameter F test:         F=25.6097 , p=0.0000  , df_denom=908, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=14.8125 , p=0.0000  , df_denom=905, df_num=2
# ssr based chi2 test:   chi2=29.7886 , p=0.0000  , df=2
# likelihood ratio test: chi2=29.3114 , p=0.0000  , df=2
# parameter F test:         F=14.8125 , p=0.0000  , df_denom=905, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=10.1968 , p=0.0000  , df_denom=902, df_num=3
# ssr based chi2 test:   chi2=30.8278 , p=0.0000  , df=3
# likelihood ratio test: chi2=30.3166 , p=0.0000  , df=3
# parameter F test:         F=10.1968 , p=0.0000  , df_denom=902, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=8.0412  , p=0.0000  , df_denom=899, df_num=4
# ssr based chi2 test:   chi2=32.4868 , p=0.0000  , df=4
# likelihood ratio test: chi2=31.9192 , p=0.0000  , df=4
# parameter F test:         F=8.0412  , p=0.0000  , df_denom=899, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=6.4612  , p=0.0000  , df_denom=896, df_num=5
# ssr based chi2 test:   chi2=32.7026 , p=0.0000  , df=5
# likelihood ratio test: chi2=32.1269 , p=0.0000  , df=5
# parameter F test:         F=6.4612  , p=0.0000  , df_denom=896, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=6.9347  , p=0.0000  , df_denom=893, df_num=6
# ssr based chi2 test:   chi2=42.2138 , p=0.0000  , df=6
# likelihood ratio test: chi2=41.2599 , p=0.0000  , df=6
# parameter F test:         F=6.9347  , p=0.0000  , df_denom=893, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=6.0510  , p=0.0000  , df_denom=890, df_num=7
# ssr based chi2 test:   chi2=43.0708 , p=0.0000  , df=7
# likelihood ratio test: chi2=42.0773 , p=0.0000  , df=7
# parameter F test:         F=6.0510  , p=0.0000  , df_denom=890, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=4.8760  , p=0.0000  , df_denom=887, df_num=8
# ssr based chi2 test:   chi2=39.7554 , p=0.0000  , df=8
# likelihood ratio test: chi2=38.9060 , p=0.0000  , df=8
# parameter F test:         F=4.8760  , p=0.0000  , df_denom=887, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=4.3157  , p=0.0000  , df_denom=884, df_num=9
# ssr based chi2 test:   chi2=39.6762 , p=0.0000  , df=9
# likelihood ratio test: chi2=38.8293 , p=0.0000  , df=9
# parameter F test:         F=4.3157  , p=0.0000  , df_denom=884, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=3.9891  , p=0.0000  , df_denom=881, df_num=10
# ssr based chi2 test:   chi2=40.8420 , p=0.0000  , df=10
# likelihood ratio test: chi2=39.9444 , p=0.0000  , df=10
# parameter F test:         F=3.9891  , p=0.0000  , df_denom=881, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=3.9865  , p=0.0000  , df_denom=878, df_num=11
# ssr based chi2 test:   chi2=45.0006 , p=0.0000  , df=11
# likelihood ratio test: chi2=43.9128 , p=0.0000  , df=11
# parameter F test:         F=3.9865  , p=0.0000  , df_denom=878, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=3.0932  , p=0.0003  , df_denom=875, df_num=12
# ssr based chi2 test:   chi2=38.1787 , p=0.0001  , df=12
# likelihood ratio test: chi2=37.3911 , p=0.0002  , df=12
# parameter F test:         F=3.0932  , p=0.0003  , df_denom=875, df_num=12

# %% [markdown]
# 이 경우, 모든 지연에서 전력 소요량의 변화가 평균 기온의 변화의 변화를 유발한다고 검정되었습니다. 이는 상식적으로 말이 되지 않습니다. 때문에 Granger Causality를 일반적인 인과관계로 그대로 해석하는 것은 경계해야하며 해석에 주의해야 합니다.

# %% [markdown]
# ## Granger Causality 문제점
#
# 그레인저 인과성 검정은 통계적인 유의성을 기반으로 인과 관계를 확인하는 것이지, 실제로 원인과 결과 사이의 인과 관계가 존재한다는 것을 입증하는 것은 아닙니다. 따라서 실제 상황에서는 이러한 검정 결과를 더 깊게 해석하고 다른 방법과 함께 고려해야 합니다.
#
# ### Linearity
#
# Granger Causality는 linear model이기 때문에 non-linear한 인과 관계는 설명할 수 없습니다.
#
# ### Stationarity
#
# Granger Causality는 데이터의 정상성을 전제로 합니다. 때문에 데이터가 정상성에서 어긋날 경우, 검정 결과의 신뢰성이 떨어집니다.
#
# ### Dependence on observed variables
# X, Y, Z 3개의 변수가 있고, Z가 X와 Y의 숨겨진 원인이라고 가정해보겠습니다. 그런데 Z의 영향으로 X는 빨리 변하고, Z의 영향으로 Y는 천천히 변할 때, X와 Y를 Granger Causality Test를 돌리면 X가 Y를 Grand Causal 한다는 잘못된 결론이 나올 수 있습니다.

# %% [markdown]
# ## Granger Causality 응용 사례
#
# 경제 성장과 소득 분배 사이에 Granger Causality Test를 진행한 연구가 있어서 인용해왔습니다.
#
# - 과거의 경제 성장은 소득 분배에 통계적으로 유의한 영향을 미침
# - 반면에 과거의 소득 분배는 현재의 경제 성장에 유의미한 영향을 미치지 못함
# - 즉, 경제 성장은 소득 분배에 Granger Causal 한다고 볼 수 있음.

# %% [markdown]
# ## 정리
#
# 이번 챕터에서는 시계열 데이터 간의 상호 인과 관계를 간접적으로 파악할 수 있는 Granger Causality Test에 대해서 배워보았습니다. 이는 시계열 데이터에서 인사이트를 뽑아낼 때 유용하게 사용될 수 있습니다. 하지만 이는 해석에 주의를 필요로 함으로, 도메인 지식을 활용하여 적절히 사용하길 바랍니다.
