# %% [markdown]
# ## Decision Tree Classifier를 이용한 와인 품질 분류하기
#
# 대회 링크: https://dacon.io/competitions/open/235610/overview/description
#
# ![image.png](attachment:7ff2f586-8e96-4922-904a-ab5015df67dc.png)

# %% [markdown]
# 지금까지 익힌 skill들을 바탕으로 데이콘 와인 품질 분류 경진대회에 참여해보세요. 팀원들과 함께 논의하여 좋은 성능의 모델을 만들어서 제출해봅시다.

# %% [markdown]
# ### 요구사항
#
# - 데이터 특성 파악하기
# - 와인 품질에 영향을 미치는 요소 파악하기
# - 데이터 전처리하기
# - decision tree 계열 알고리즘을 사용하여 분류 모델 학습시키고 교차 검증하기
# - 테스트 셋에 대하여 인퍼런스 한 뒤, 플랫폼에 적어도 한번 결과 제출하기
