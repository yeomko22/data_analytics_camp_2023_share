# %% [markdown]
# # Practice 3. torch MLP classification
#
# 버섯의 정보를 가지고 먹을 수 있는지 없는지 분류하는 모델을 Multilayer Perceptron 모델을 이용해서 만들어보세요. 그리고 성능 개선 효과가 있는지 로지스틱 리그레션 모델과 비교해보세요.
#
# 데이터 셋 링크: https://www.kaggle.com/datasets/uciml/mushroom-classification

# %%
import pandas as pd

df = pd.read_csv("./data/mushrooms.csv")

# %%
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...
